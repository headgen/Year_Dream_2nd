# %%
from IPython.display import Image
import seaborn as sns
# Out:
# C:\Users\Han\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
Image('pic1.jpg')

# %%
palette1 = ['#68F394','#B385EF','#4BD4FE','#FCD323','#EEEFF1']
sns.palplot(palette1)

# %%
Image('pic2.png')

# %%
palette2 = ['#0C84A5','#F7C860','#6F4E7B','#9DD766','#C9472F']
sns.palplot(palette2)

# %%
Image('pic3.png')

# %%
palette3 = ['#76677A','#F5C767','#5C96A4']
sns.palplot(palette3)

# %%
Image('pic4.png')

# %%
palette4 = ['#C7D4B6','#A3AABD','#A0D0DE','#97B5CF']
sns.palplot(palette4)
